# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.241051
# Nearest to some: sacr, tropic, bottleneck, compatriots, dictator, geller, dairy, storyteller,
# Nearest to system: eduskunta, fishery, oppression, brooklyn, syndicates, habsburg, available, wagons,
# Nearest to if: obstructions, discrimination, packed, dev, teamed, anemia, matlab, charlton,
# Nearest to which: michele, ouagadougou, occuring, perforated, symbols, waw, embalming, talented,
# Nearest to at: pearse, kets, ej, ozzfest, centralization, weeping, prior, gne,
# Nearest to state: gadol, iridium, wink, heirs, coursing, alla, dunedin, electrolytic,
# Nearest to about: sprang, laments, windsurfing, nests, akkadian, chef, cmf, marius,
# Nearest to war: latinus, studio, strand, misr, roadways, surpasses, accompany, hbox,
# Nearest to many: trevor, finches, wilbur, mitchell, cigarette, ramayana, steeple, crunch,
# Nearest to six: spotless, annoy, free, degree, venera, hartley, aramaic, landforms,
# Nearest to four: tying, eat, subtrees, paints, conduct, cheated, ann, duct,
# Nearest to more: violet, corvettes, essenes, kes, merrill, essene, dijon, woodcuts,
# Nearest to into: mugabe, goth, coerce, grigory, martel, meir, future, seizure,
# Nearest to all: sutherland, scapegoat, trumpet, webpages, webcams, atemi, purest, centrality,
# Nearest to between: hearted, mayday, spoilage, abitibi, woodwinds, televised, archtop, optimized,
# Nearest to can: airliner, graham, charter, introducing, wooded, emphasises, directrix, ashur,
# Average loss at step 2000: 4.366885
# Average loss at step 4000: 3.870744
# Average loss at step 6000: 3.787125
# Average loss at step 8000: 3.685349
# Average loss at step 10000: 3.609372
# Nearest to some: many, any, xinjiang, esse, alien, dictator, rnzaf, confederate,
# Nearest to system: fishery, genre, eduskunta, allein, photosynthetic, hawai, wagons, available,
# Nearest to if: geo, discrimination, geffen, obstructions, clairvaux, dev, isn, kish,
# Nearest to which: that, this, he, also, it, michele, jerky, pubs,
# Nearest to at: in, on, from, corvettes, meals, segmentata, by, between,
# Nearest to state: electrolytic, rink, wink, arguing, silicone, lenoir, hexokinase, prospect,
# Nearest to about: artefacts, akkadian, made, epidemiology, cryptanalytic, imac, regi, perched,
# Nearest to war: studio, latinus, hbox, misr, strand, ehrlich, mothman, ice,
# Nearest to many: some, finches, gore, most, several, various, jackson, predestination,
# Nearest to six: eight, seven, four, five, three, nine, zero, two,
# Nearest to four: six, eight, five, seven, three, two, nine, zero,
# Nearest to more: woodcuts, less, regret, specifying, mediawiki, generalitat, confidently, often,
# Nearest to into: by, from, as, sewage, personal, unintelligent, williams, in,
# Nearest to all: sutherland, trumpet, crewed, handwriting, persecution, increased, crusading, die,
# Nearest to between: with, hearted, idle, vegetarianism, equilibrium, mayday, wobble, on,
# Nearest to can: may, airliner, would, melrose, graham, introducing, restyled, should,
# Average loss at step 12000: 3.606399
# Average loss at step 14000: 3.574760
# Average loss at step 16000: 3.406112
# Average loss at step 18000: 3.455482
# Average loss at step 20000: 3.538199
# Nearest to some: many, several, these, any, most, the, xinjiang, sedative,
# Nearest to system: fishery, genre, allein, wagons, folders, eduskunta, cymru, photosynthetic,
# Nearest to if: isn, clairvaux, kish, where, when, obfuscation, discrimination, since,
# Nearest to which: that, this, who, also, it, there, but, he,
# Nearest to at: in, from, on, meals, and, after, documents, with,
# Nearest to state: electrolytic, lenoir, rink, paraphrase, doves, hexokinase, garner, converges,
# Nearest to about: artefacts, duplicates, lindow, recorders, forall, regi, akkadian, made,
# Nearest to war: latinus, studio, hbox, minarchists, gpled, misr, diagnoses, ancestors,
# Nearest to many: some, several, these, all, various, other, finches, most,
# Nearest to six: five, seven, eight, three, four, nine, zero, two,
# Nearest to four: three, six, seven, five, eight, nine, two, zero,
# Nearest to more: less, most, woodcuts, rather, regret, generalitat, stockport, longer,
# Nearest to into: from, by, unintelligent, unlike, future, williams, lesbians, uta,
# Nearest to all: many, these, sutherland, crewed, some, handwriting, persecution, cyclades,
# Nearest to between: with, from, in, mayday, hearted, idle, wobble, aragorn,
# Nearest to can: may, would, should, must, could, will, cannot, rentals,
# Average loss at step 22000: 3.503012
# Average loss at step 24000: 3.484126
# Average loss at step 26000: 3.482950
# Average loss at step 28000: 3.480617
# Average loss at step 30000: 3.509604
# Nearest to some: many, several, these, all, any, their, rnzaf, those,
# Nearest to system: systems, genre, palette, notices, hawai, fishery, stryker, cymru,
# Nearest to if: when, isn, where, obfuscation, leaving, aussie, marketshare, chao,
# Nearest to which: that, this, what, also, but, it, who, there,
# Nearest to at: in, meals, during, macao, schistosomiasis, on, after, throughout,
# Nearest to state: paraphrase, rink, electrolytic, salmon, lenoir, converges, predictable, wink,
# Nearest to about: duplicates, recorders, artefacts, macintoshes, forall, tora, bacardi, akkadian,
# Nearest to war: hbox, gpled, latinus, misr, studio, diagnoses, deputy, cnn,
# Nearest to many: some, several, these, most, all, both, various, those,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to four: five, seven, six, three, eight, nine, two, zero,
# Nearest to more: less, most, rather, anatta, woodcuts, specifying, larger, longer,
# Nearest to into: from, unlike, unintelligent, by, sewage, initial, lesbians, uta,
# Nearest to all: some, these, ontogeny, many, persecution, crewed, control, handwriting,
# Nearest to between: with, mayday, idle, hearted, from, clitoris, on, wobble,
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Average loss at step 32000: 3.502991
# Average loss at step 34000: 3.490109
# Average loss at step 36000: 3.451577
# Average loss at step 38000: 3.302152
# Average loss at step 40000: 3.427203
# Nearest to some: many, several, these, any, rnzaf, their, various, the,
# Nearest to system: systems, palette, genre, hawai, fishery, pi, folders, privileges,
# Nearest to if: when, where, isn, is, chao, that, subpixel, though,
# Nearest to which: that, this, it, who, what, also, there, these,
# Nearest to at: during, on, macao, ducts, overgrown, schistosomiasis, throughout, in,
# Nearest to state: government, converges, paraphrase, rink, predictable, electrolytic, wink, salmon,
# Nearest to about: duplicates, artefacts, recorders, forall, llu, tora, dissipation, epidemiology,
# Nearest to war: cnn, studio, diagnoses, earth, deputy, hbox, minarchists, zambian,
# Nearest to many: some, several, these, various, both, those, most, numerous,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to four: three, six, seven, eight, five, two, nine, one,
# Nearest to more: less, most, very, specifying, woodcuts, larger, thousand, rather,
# Nearest to into: from, unlike, unintelligent, uta, lesbians, emissaries, correspondents, through,
# Nearest to all: ontogeny, handwriting, victory, these, crewed, control, several, any,
# Nearest to between: with, mayday, among, against, from, idle, liege, hearted,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Average loss at step 42000: 3.430801
# Average loss at step 44000: 3.457143
# Average loss at step 46000: 3.445572
# Average loss at step 48000: 3.353824
# Average loss at step 50000: 3.378508
# Nearest to some: many, several, these, any, various, both, those, their,
# Nearest to system: systems, pi, fishery, palette, stryker, satirists, notices, genre,
# Nearest to if: when, where, isn, although, though, chao, subpixel, while,
# Nearest to which: that, this, who, also, what, but, still, often,
# Nearest to at: during, on, in, ducts, overgrown, throughout, from, shakespearean,
# Nearest to state: government, rink, converges, wink, predictable, electrolytic, labour, garner,
# Nearest to about: artefacts, duplicates, recorders, dissipation, forall, macintoshes, bb, creatures,
# Nearest to war: cnn, diagnoses, deputy, minarchists, earth, studio, misr, inverse,
# Nearest to many: some, several, both, these, various, those, other, most,
# Nearest to six: eight, seven, four, nine, three, five, two, zero,
# Nearest to four: five, seven, six, eight, three, nine, two, zero,
# Nearest to more: less, most, very, increasingly, specifying, longer, larger, woodcuts,
# Nearest to into: from, through, uta, unintelligent, unlike, agronomy, correspondents, by,
# Nearest to all: these, both, many, any, out, some, infidel, reels,
# Nearest to between: with, among, against, mayday, idle, from, in, clitoris,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Average loss at step 52000: 3.437467
# Average loss at step 54000: 3.423049
# Average loss at step 56000: 3.438777
# Average loss at step 58000: 3.395084
# Average loss at step 60000: 3.391027
# Nearest to some: many, several, these, most, various, any, both, all,
# Nearest to system: systems, palette, deciphered, levels, cabo, fishery, notices, capricorn,
# Nearest to if: when, where, isn, then, though, because, before, although,
# Nearest to which: that, this, what, who, these, but, ailments, heimdall,
# Nearest to at: ducts, meals, without, in, shakespearean, overgrown, during, throughout,
# Nearest to state: government, labour, converges, hexokinase, rink, predictable, gigue, electrolytic,
# Nearest to about: artefacts, recorders, forall, duplicates, guignol, editorial, regi, bacardi,
# Nearest to war: cnn, diagnoses, deputy, minarchists, bloomberg, inverse, tanaka, guy,
# Nearest to many: some, several, various, these, both, most, all, ghb,
# Nearest to six: eight, five, four, nine, seven, three, two, zero,
# Nearest to four: five, eight, six, seven, three, nine, zero, two,
# Nearest to more: less, most, very, better, increasingly, longer, rather, specifying,
# Nearest to into: through, from, unlike, lithography, across, uta, organisers, unintelligent,
# Nearest to all: many, both, any, some, these, those, ontogeny, reels,
# Nearest to between: with, among, in, against, azrael, from, wobble, within,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Average loss at step 62000: 3.241655
# Average loss at step 64000: 3.251314
# Average loss at step 66000: 3.405433
# Average loss at step 68000: 3.391771
# Average loss at step 70000: 3.356101
# Nearest to some: many, several, these, both, all, various, most, those,
# Nearest to system: systems, deciphered, cabo, compromises, fishery, hawai, xie, pickups,
# Nearest to if: when, where, because, though, before, isn, after, although,
# Nearest to which: that, this, but, what, also, who, these, and,
# Nearest to at: ducts, in, without, overgrown, on, meals, during, macao,
# Nearest to state: government, converges, labour, states, predictable, city, hexokinase, espoo,
# Nearest to about: artefacts, over, recorders, duplicates, forall, robberies, approximately, dissipation,
# Nearest to war: diagnoses, cnn, deputy, isaac, minarchists, inverse, zambian, bongo,
# Nearest to many: some, several, various, these, both, all, most, numerous,
# Nearest to six: eight, four, five, nine, seven, three, two, zero,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to more: less, most, very, longer, rather, specifying, increasingly, larger,
# Nearest to into: from, through, within, across, emissaries, unlike, incorporates, organisers,
# Nearest to all: many, some, any, both, various, those, pulsation, these,
# Nearest to between: with, among, from, cock, within, in, likewise, mayday,
# Nearest to can: may, could, must, would, will, cannot, should, might,
# Average loss at step 72000: 3.374595
# Average loss at step 74000: 3.347125
# Average loss at step 76000: 3.321675
# Average loss at step 78000: 3.348808
# Average loss at step 80000: 3.373892
# Nearest to some: many, several, these, various, most, both, all, those,
# Nearest to system: systems, thucydides, cabo, capricorn, hawai, cytosine, jehoash, xie,
# Nearest to if: when, though, before, then, because, where, does, isn,
# Nearest to which: that, this, also, freeh, what, itself, thucydides, who,
# Nearest to at: in, on, during, before, after, meals, ducts, without,
# Nearest to state: government, city, labour, garner, agricola, wink, frictional, converges,
# Nearest to about: artefacts, approximately, recorders, duplicates, over, majestic, robberies, regi,
# Nearest to war: diagnoses, cnn, wars, deputy, shone, isaac, mothman, latinus,
# Nearest to many: some, several, various, these, both, most, numerous, all,
# Nearest to six: five, eight, four, seven, three, nine, two, zero,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to more: less, very, most, longer, better, rather, invested, extremely,
# Nearest to into: through, from, within, across, unlike, hindsight, unintelligent, organisers,
# Nearest to all: both, any, many, some, every, various, these, balked,
# Nearest to between: with, among, within, from, over, clitoris, in, cock,
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Average loss at step 82000: 3.409864
# Average loss at step 84000: 3.409951
# Average loss at step 86000: 3.387330
# Average loss at step 88000: 3.350527
# Average loss at step 90000: 3.363413
# Nearest to some: many, several, these, any, all, both, various, certain,
# Nearest to system: systems, monorail, definition, asteroid, palette, notices, postmodernism, himalayas,
# Nearest to if: when, where, before, though, after, then, so, isn,
# Nearest to which: that, this, also, what, itself, actually, but, who,
# Nearest to at: on, after, during, without, before, meals, under, near,
# Nearest to state: government, city, labour, wink, garner, predictable, szasz, converges,
# Nearest to about: artefacts, approximately, over, duplicates, lauter, dissipation, regi, recorders,
# Nearest to war: cnn, diagnoses, wars, shone, deputy, minarchists, protest, inverse,
# Nearest to many: several, some, various, these, all, most, numerous, both,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to more: less, most, very, rather, better, increasingly, longer, mediawiki,
# Nearest to into: from, through, across, within, unintelligent, organisers, offshore, lithography,
# Nearest to all: many, both, some, several, any, pulsation, various, reels,
# Nearest to between: with, from, among, within, in, during, cock, likewise,
# Nearest to can: could, may, must, would, will, should, cannot, might,
# Average loss at step 92000: 3.398532
# Average loss at step 94000: 3.254297
# Average loss at step 96000: 3.353570
# Average loss at step 98000: 3.240987
# Average loss at step 100000: 3.355201
# Nearest to some: many, several, these, any, various, certain, numerous, all,
# Nearest to system: systems, definition, postmodernism, commodus, hawai, romagna, theory, fishery,
# Nearest to if: when, where, before, because, isn, though, then, grille,
# Nearest to which: that, this, what, actually, these, also, who, itself,
# Nearest to at: on, meals, without, during, after, in, overgrown, near,
# Nearest to state: city, government, labour, securely, szasz, states, polyhedra, agricola,
# Nearest to about: artefacts, approximately, recorders, duplicates, lauter, regi, cmf, dissipation,
# Nearest to war: cnn, diagnoses, wars, shone, championships, napol, protest, inverse,
# Nearest to many: several, some, various, these, all, numerous, few, most,
# Nearest to six: seven, four, eight, nine, five, three, two, zero,
# Nearest to four: six, seven, five, eight, nine, three, two, zero,
# Nearest to more: less, most, very, larger, better, increasingly, rather, longer,
# Nearest to into: through, from, within, across, unlike, in, out, organisers,
# Nearest to all: many, various, any, both, several, those, some, these,
# Nearest to between: with, among, likewise, helga, cock, from, in, within,
# Nearest to can: may, could, must, will, would, should, cannot, might,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.985772
# Nearest to one: tze, fulbright, untrue, bene, certain, lg, chimes, shook,
# Nearest to during: roost, seleucus, decrees, dogma, bing, daley, gulliver, tricolor,
# Nearest to only: spoilage, lugs, balaton, stake, inverting, overzealous, hymnal, aloud,
# Nearest to who: petronas, drc, nightmarish, clg, grizzly, lighthouse, brokered, cloudy,
# Nearest to have: moyers, kaaba, soups, secondly, interrogated, unsuspecting, colder, botha,
# Nearest to i: paraphyletic, reginae, corinthian, xor, osu, rebirth, microelectronics, neopagan,
# Nearest to use: piran, share, chilled, adolescents, latvians, acting, phenylalanine, worldcon,
# Nearest to up: combatants, pain, neighbor, kabbalists, africanus, pars, penile, lettuce,
# Nearest to states: kongo, hereafter, diggers, pigpen, arafat, subjunctive, counselor, neberg,
# Nearest to over: gab, stirring, bourke, hinge, adenylate, langford, kinsman, energies,
# Nearest to be: windward, york, charterer, aerobic, altay, cayley, nodules, surpass,
# Nearest to and: lily, fortnight, overseer, devise, exclaimed, restatement, layers, kerenyi,
# Nearest to is: horrible, northumbrian, mpls, chmielnicki, proud, erasing, touted, logics,
# Nearest to many: angli, wi, dtft, burst, folder, lucasarts, spite, gions,
# Nearest to all: imprint, arsenal, sect, godf, monists, kinsman, kohoutek, clover,
# Nearest to war: austrasia, judging, downward, fullness, gags, maidstone, diglossia, digraph,
# Average loss at step 2000: 7.157227
# Average loss at step 4000: 4.834788
# Average loss at step 6000: 4.873258
# Average loss at step 8000: 4.291954
# Average loss at step 10000: 4.310319
# Nearest to one: bestowing, incarceration, photographing, anteaters, ratios, culver, administratives, terrorist,
# Nearest to during: for, hydrophobic, proteins, howard, of, image, is, while,
# Nearest to only: even, certain, vu, outfits, rounds, spoilage, elaborating, drinker,
# Nearest to who: he, which, waiting, fairy, unfairness, narn, alb, pointy,
# Nearest to have: had, has, be, by, having, are, curves, embodying,
# Nearest to i: proteins, image, the, is, nh, howard, hydrophobic, cl,
# Nearest to use: redness, piran, cossiga, kazakhstani, widths, magnetometer, banach, transports,
# Nearest to up: bouillon, chievo, kabbalists, climatic, gioacchino, neighbor, bjorn, penile,
# Nearest to states: pal, town, values, idea, nh, is, xix, alpaca,
# Nearest to over: fishery, million, whipped, sperry, turrets, brezhnev, squared, affaires,
# Nearest to be: is, proteins, hydrophobic, the, howard, nh, that, fuel,
# Nearest to and: or, while, for, of, cataracts, the, two, that,
# Nearest to is: hydrophobic, howard, image, proteins, the, or, nh, are,
# Nearest to many: some, several, other, most, lodge, all, supper, cygwin,
# Nearest to all: msp, many, triads, deleuze, sandinista, conceal, unheated, some,
# Nearest to war: ample, pier, discouraged, convention, bolivia, expound, airbase, recieved,
# Average loss at step 12000: 4.121131
# Average loss at step 14000: 3.872084
# Average loss at step 16000: 3.843789
# Average loss at step 18000: 3.631550
# Average loss at step 20000: 3.754213
# Nearest to one: two, five, depending, principal, lookahead, individual, aborted, caucasus,
# Nearest to during: before, in, against, since, throughout, until, stingray, first,
# Nearest to only: gps, brussels, n, bob, hydrophobic, nh, roads, normal,
# Nearest to who: which, he, narn, that, cowper, patricia, strips, blends,
# Nearest to have: has, had, having, are, be, were, refer, ve,
# Nearest to i: ii, we, you, g, uncommonly, cleared, bothered, exons,
# Nearest to use: describe, form, avenida, uncivilized, mixture, hannes, redness, ace,
# Nearest to up: down, judas, bomb, out, climatic, bouillon, pars, penile,
# Nearest to states: kingdom, nations, lilith, diggers, maximin, ploughing, subjunctive, finland,
# Nearest to over: at, blasting, across, before, during, zealot, thousand, through,
# Nearest to be: refer, being, keep, cause, include, are, have, afford,
# Nearest to and: while, or, which, yukio, including, sadat, but, puppeteer,
# Nearest to is: was, are, became, were, has, means, diodes, servitude,
# Nearest to many: some, several, various, all, those, these, numerous, lycopene,
# Nearest to all: several, various, deleuze, many, these, different, some, collections,
# Nearest to war: season, ample, discouraged, irene, averroes, dynasty, redesignated, skylab,
# Average loss at step 22000: 3.683944
# Average loss at step 24000: 3.465390
# Average loss at step 26000: 3.421678
# Average loss at step 28000: 3.456656
# Average loss at step 30000: 3.375977
# Nearest to one: two, interbreeding, minden, decrement, cryptids, clogged, negus, assemblers,
# Nearest to during: throughout, after, before, until, in, against, since, over,
# Nearest to only: always, usually, shortened, resolute, meir, unproductive, gentrification, aperture,
# Nearest to who: which, that, young, chakra, by, goss, inaccurate, he,
# Nearest to have: has, had, having, include, are, provide, refer, ve,
# Nearest to i: g, we, ii, you, hypergeometric, unesco, bothered, they,
# Nearest to use: exist, isn, play, form, think, describe, version, aid,
# Nearest to up: off, out, back, bomb, marjoram, stiff, altruism, fifa,
# Nearest to states: kingdom, nations, maximin, angelica, arginine, salem, schwa, subjunctive,
# Nearest to over: through, across, around, during, blasting, at, before, thousand,
# Nearest to be: refer, being, become, remain, migrate, secularism, been, move,
# Nearest to and: while, or, but, edith, courses, with, larnaca, hadrons,
# Nearest to is: was, are, became, has, becomes, contains, makes, occurs,
# Nearest to many: some, several, various, all, most, neoplatonic, those, few,
# Nearest to all: both, several, some, various, many, normandy, these, opponents,
# Nearest to war: ample, convention, guzm, airbase, pva, around, hymnal, dynasty,
# Average loss at step 32000: 3.146443
# Average loss at step 34000: 3.312518
# Average loss at step 36000: 3.465571
# Average loss at step 38000: 3.399829
# Average loss at step 40000: 3.326559
# Nearest to one: bargain, boopsie, sands, zyklon, booking, storytellers, marshland, donkeys,
# Nearest to during: in, after, throughout, before, within, until, over, through,
# Nearest to only: coen, earliest, always, reputations, alarmed, bre, cgi, therefore,
# Nearest to who: goss, sbc, she, he, actually, young, oven, trough,
# Nearest to have: had, carry, ruth, offence, carbine, marche, brussels, anthropology,
# Nearest to i: ii, g, loses, mail, mitochondria, julian, v, peru,
# Nearest to use: addicted, existentialism, think, antiquity, presence, because, describe, play,
# Nearest to up: off, out, down, bomb, sipe, octahedra, secessionist, navigate,
# Nearest to states: kingdom, nations, nakano, schwa, maximin, subjunctive, licenses, emirates,
# Nearest to over: across, during, through, at, parthian, within, blasting, between,
# Nearest to be: being, refer, lead, produce, were, been, afford, remain,
# Nearest to and: or, while, including, although, blueprint, but, minnesotans, sadat,
# Nearest to is: was, are, became, were, becomes, remains, has, includes,
# Nearest to many: several, some, various, all, numerous, most, few, bibliographies,
# Nearest to all: various, many, every, several, mainly, some, these, expelling,
# Nearest to war: encoding, julian, megiddo, fas, howard, carbine, tnf, anthropology,
# Average loss at step 42000: 3.357822
# Average loss at step 44000: 3.252591
# Average loss at step 46000: 3.283815
# Average loss at step 48000: 3.177138
# Average loss at step 50000: 3.142929
# Nearest to one: sands, thrived, abv, overpopulation, vaz, await, interested, halfdan,
# Nearest to during: after, throughout, in, until, within, despite, before, at,
# Nearest to only: always, even, witwatersrand, crtc, earliest, jury, wiping, already,
# Nearest to who: young, he, which, living, lafur, karsh, goss, grin,
# Nearest to have: has, had, having, require, provide, produce, were, contain,
# Nearest to i: g, mail, ii, we, you, lai, decides, anterior,
# Nearest to use: history, purpose, advent, institute, practice, inexplicably, carburetor, subsumed,
# Nearest to up: off, out, together, back, forth, robots, him, sayyaf,
# Nearest to states: kingdom, nations, subjunctive, schwa, emirates, elector, nakano, mohenjo,
# Nearest to over: beloved, around, following, before, outside, across, linear, transitional,
# Nearest to be: being, refer, remain, lead, take, occur, mean, yield,
# Nearest to and: or, while, including, than, but, however, edna, tautologies,
# Nearest to is: was, are, makes, has, contains, means, became, were,
# Nearest to many: several, some, various, all, most, these, few, number,
# Nearest to all: various, many, these, deleuze, some, several, both, denumerable,
# Nearest to war: guzm, wars, beaton, roundabout, maturing, shaun, ample, dynasty,
# Average loss at step 52000: 3.212173
# Average loss at step 54000: 3.172582
# Average loss at step 56000: 3.012480
# Average loss at step 58000: 3.123286
# Average loss at step 60000: 3.130798
# Nearest to one: honestly, schulz, earthman, paranoia, two, halfdan, eighty, sands,
# Nearest to during: before, after, in, until, since, throughout, within, despite,
# Nearest to only: actually, always, even, fold, crtc, stalling, caeiro, earliest,
# Nearest to who: goss, he, which, monasteries, tilsit, already, fanaticism, jesse,
# Nearest to have: has, had, having, require, provide, contain, include, are,
# Nearest to i: ii, you, we, lai, ziibi, preparedness, mail, candle,
# Nearest to use: describe, apply, natufian, exist, addition, think, faust, understand,
# Nearest to up: off, down, out, conduction, back, together, reginae, ferry,
# Nearest to states: kingdom, nations, countries, provinces, emirates, liturgics, ours, churches,
# Nearest to over: hg, offence, carbine, hydrophobic, vert, magnon, ocp, nh,
# Nearest to be: refer, remain, lead, being, produce, have, exist, become,
# Nearest to and: or, but, while, musashi, although, however, igneous, than,
# Nearest to is: was, are, has, becomes, includes, means, exists, were,
# Nearest to many: several, some, various, all, those, certain, most, few,
# Nearest to all: many, some, several, every, various, israel, drummond, curling,
# Nearest to war: guzm, wars, shaun, flasks, dynasty, ample, diglossia, slurry,
# Average loss at step 62000: 3.111627
# Average loss at step 64000: 3.078922
# Average loss at step 66000: 3.079080
# Average loss at step 68000: 3.052656
# Average loss at step 70000: 3.107265
# Nearest to one: brussels, anthropology, polish, ruth, carbine, gps, nh, vert,
# Nearest to during: after, throughout, before, since, within, until, in, involves,
# Nearest to only: signifying, intact, unproductive, dominos, particularly, even, therefore, stalling,
# Nearest to who: young, he, which, that, already, launceston, whose, longman,
# Nearest to have: had, has, having, provide, require, contain, include, produce,
# Nearest to i: we, ii, you, lai, g, mail, candle, they,
# Nearest to use: think, apply, describe, implementation, silky, inexplicably, study, collection,
# Nearest to up: off, down, out, back, secessionist, barrington, forth, together,
# Nearest to states: kingdom, nations, emirates, liturgics, mohenjo, provinces, domicile, nakano,
# Nearest to over: blasting, around, into, yoke, within, regime, about, rebellions,
# Nearest to be: being, lead, refer, remain, cause, occur, produce, yield,
# Nearest to and: or, but, including, although, however, sw, musashi, launceston,
# Nearest to is: was, are, makes, remains, has, became, includes, provides,
# Nearest to many: some, several, various, all, certain, numerous, both, these,
# Nearest to all: many, both, various, certain, deleuze, several, some, every,
# Nearest to war: wars, julian, bedouins, fangio, series, campaign, magnon, behaviors,
# Average loss at step 72000: 3.063207
# Average loss at step 74000: 2.973601
# Average loss at step 76000: 3.132280
# Average loss at step 78000: 3.075669
# Average loss at step 80000: 2.906814
# Nearest to one: zyklon, earthman, storytellers, workhorse, bestowing, unsigned, ahaziah, blockading,
# Nearest to during: throughout, after, before, in, within, until, at, involves,
# Nearest to only: currently, ussr, whether, carbine, governments, required, dtv, ocp,
# Nearest to who: which, whom, goss, young, whose, he, by, she,
# Nearest to have: had, having, has, carry, produce, provide, require, offer,
# Nearest to i: ii, we, you, g, iii, they, decides, mail,
# Nearest to use: form, pursuit, apply, addition, presence, inertia, introduction, advent,
# Nearest to up: down, off, out, back, secessionist, together, barrington, forth,
# Nearest to states: kingdom, nations, provinces, religions, emirates, dtv, residents, iy,
# Nearest to over: around, blasting, about, throughout, surrounding, parthian, during, cmd,
# Nearest to be: refer, remain, being, lead, represent, occur, provide, yield,
# Nearest to and: or, including, but, etc, minnesotans, although, while, like,
# Nearest to is: was, are, makes, includes, has, became, exists, contains,
# Nearest to many: some, several, numerous, various, both, those, most, all,
# Nearest to all: various, any, both, some, always, every, many, several,
# Nearest to war: wars, hymnal, revolution, phys, shaun, roundabout, explosion, airbase,
# Average loss at step 82000: 2.987294
# Average loss at step 84000: 2.950970
# Average loss at step 86000: 2.975450
# Average loss at step 88000: 3.000188
# Average loss at step 90000: 2.891612
# Nearest to one: zyklon, blockading, two, wyatt, marshland, bestowing, sufferer, storytellers,
# Nearest to during: after, until, in, before, throughout, around, since, involves,
# Nearest to only: always, still, particularly, ever, multiverse, it, no, even,
# Nearest to who: whom, which, typically, narn, always, tsing, finned, traditionally,
# Nearest to have: has, had, having, require, contain, create, ve, provide,
# Nearest to i: ii, mail, iii, g, erectile, we, holberg, antiderivative,
# Nearest to use: usage, support, form, because, apply, think, introduction, amount,
# Nearest to up: off, down, out, separating, back, together, forth, conduction,
# Nearest to states: kingdom, nations, emirates, provinces, says, users, liturgics, freighter,
# Nearest to over: around, throughout, during, within, blasting, surrounding, rebellions, about,
# Nearest to be: refer, lead, remain, yield, serve, represent, being, provide,
# Nearest to and: or, while, but, etc, including, although, precept, crystallographic,
# Nearest to is: was, are, includes, became, has, becomes, provides, makes,
# Nearest to many: carbine, ruth, legitimacy, atp, advocate, yugoslavia, physiological, fadh,
# Nearest to all: always, various, every, both, deleuze, many, triads, some,
# Nearest to war: wars, roundabout, peppermint, hiding, maturing, guzm, reminder, peanuts,
# Average loss at step 92000: 2.960699
# Average loss at step 94000: 2.939214
# Average loss at step 96000: 2.937760
# Average loss at step 98000: 2.530525
# Average loss at step 100000: 2.757845
# Nearest to one: storytellers, zyklon, abv, recipient, earthman, weaker, strickland, rodeo,
# Nearest to during: in, until, at, throughout, saw, since, involves, around,
# Nearest to only: dominos, last, always, first, earliest, best, stimulate, annunciation,
# Nearest to who: whom, which, whose, young, he, typically, that, disabled,
# Nearest to have: had, has, having, contain, require, ve, produce, create,
# Nearest to i: ii, we, you, g, iii, lai, mail, hicks,
# Nearest to use: form, apply, support, amount, usage, version, presence, allow,
# Nearest to up: off, out, down, together, forth, back, secessionist, chievo,
# Nearest to states: kingdom, nations, emirates, airlines, state, azerbaijani, provinces, stasi,
# Nearest to over: around, about, off, during, away, blasting, rebellions, zealot,
# Nearest to be: remain, being, refer, lead, evolve, serve, occur, have,
# Nearest to and: or, while, but, etc, although, including, however, though,
# Nearest to is: was, are, exists, includes, has, remains, makes, became,
# Nearest to many: some, several, various, numerous, most, both, hundreds, thousands,
# Nearest to all: every, various, deleuze, ten, many, always, some, both,
# Nearest to war: wars, shaun, invasion, roundabout, revolution, maturing, mainland, bub,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
